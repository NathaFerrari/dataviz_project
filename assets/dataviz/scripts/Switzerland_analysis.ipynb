# %%
import pandas as pd
import numpy as np

# %%
# Carica il dataset
df = pd.read_csv("../DataSets/pivoted_filled_preprocessed_dataset.csv")

# Filtra solo la Svizzera
swiss_df = df[df["Reference area"] == "Switzterland"]

# (Opzionale) salva il risultato in un nuovo file
swiss_df.to_csv("../DataSets/Switzerland_pivoted_filled_preprocessed_dataset.csv", index=False)
